# %%
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd
import numpy as np
import plotly
import plotly.io as pio

# %%
coffeedata = pd.read_parquet("df_arabica_clean.parquet")
coffeedata
# Out:
#     Country of Origin                 Farm Name  \
# 0            Thailand             Ching Saethao
# 1            Thailand         Pichet Klaphithak
# 2              Brazil         Fazenda Guariroba
# 3            Thailand  Coffee De Hmong Bio Farm
# 4            Thailand     Wichai Kamnerdmongkon
# ..                ...                       ...
# 325            Taiwan       曙光的故鄉 Aurora Coffee
# 326            Taiwan                  瑞穗石柱咖啡莊園
# 327         Indonesia               KT. Bersama
# 328            Taiwan                馬耀咖啡蜜蜂生態農場
# 329             China                Lama Manor
#
#                                             Lot Number  \
# 0                                                  TCE
# 1                                                  TCE
# 2                                              RR24009
# 3                                                 2024
# 4                                                  TCE
# ...

# %%
origin = coffeedata['Region'].unique()

origin
# Out:
# array(['Nan', 'Ngop, Thung Chang, Nan', 'Minas Gerais', 'เอเชีย',
#        'Thung Chang,Nan', 'North of Thailand', 'YIRGACHEFFE KONGA',
#        'Thung Chang, Nan', 'YIRGACHEFFE ARICHA', 'Sidama',
#        'Pangkhon, Chiang Rai', 'Chae Son,Mueang Pan,Lampang',
#        'Mae Sariang, Mae Hong Son', 'East Haraz', 'Chiang Mai', 'Kochere',
#        '嘉義縣阿里山鄉 Alishan Township, Chiayi County',
#        '台中市新社區 Xinshe Dist., Taichung City',
#        '嘉義縣梅山鄉 Meishan Township, Chiayi County', 'Doi Saket, Chiangmai',
#        'Ngop, Thung Chang,Nan', 'Mbeya',
#        '台南市東山區 Dongshan Dist., Tainan City',
#        '嘉義縣番路鄉 Fanlu Township, Chiayi County', 'Narino',
#        '南投縣國姓鄉 Guoxing Township, Nantou County', 'HUILA',
#        'YIRGACHEFFEE ARICHA', '嘉義縣 竹崎鄉 Zhuqi Township, Chiayi County',
#        '花蓮縣秀林鄉 Hualien County,Show Linxia Township', 'Omkoi, Chiang Mai',
#        'Mae Fah Luang, Chiang Rai',
#        '花蓮縣萬榮鄉 Hualien County Wanrong Township',
# ...
